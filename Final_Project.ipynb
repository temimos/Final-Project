# %%
ms1.xls
total-marriages-by-marriage-order-and-age-differential-of-grooms-to-brides-annual

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Loading our data:
# !head totalmarriage.csv
# Out:
# year,level_1,value
# 1984,Total,24467
# 1984,First Marriages,22420
# 1984,Remarriages,2047
# 1985,Total,23058
# 1985,First Marriages,21085
# 1985,Remarriages,1973
# 1986,Total,19760
# 1986,First Marriages,17679
# 1986,Remarriages,2081

# %%
# del df

# %%
df = pd.read_csv('bridegroom.csv'
                )

print(df)
# Out:
#       year      level_1                           level_2  value
# 0     1984        Total                          Same Age   2506
# 1     1984        Total             Groom Older By 1 Year   3069
# 2     1984        Total            Groom Older By 2 Years   3168
# 3     1984        Total            Groom Older By 3 Years   3036
# 4     1984        Total            Groom Older By 4 Years   2590
# ...    ...          ...                               ...    ...
# 2515  2018  Remarriages          Groom Younger By 2 Years    191
# 2516  2018  Remarriages          Groom Younger By 3 Years    152
# 2517  2018  Remarriages          Groom Younger By 4 Years    141
# 2518  2018  Remarriages        Groom Younger By 5-9 Years    329
# 2519  2018  Remarriages  Groom Younger By 10 Years & Over    167
#
# [2520 rows x 4 columns]

# %%
df.head(25)
# Out:
#     year          level_1 level_2  value
# 0   1984            Total      =0   2506
# 1   1984            Total      +1   3069
# 2   1984            Total      +2   3168
# 3   1984            Total      +3   3036
# 4   1984            Total      +4   2590
# 5   1984            Total      +5   1977
# 6   1984            Total      +6   1416
# 7   1984            Total      +7   1137
# 8   1984            Total      +8    784
# 9   1984            Total      +9    516
# 10  1984            Total     +10    347
# 11  1984            Total     +11    255
# 12  1984            Total     +12    167
# 13  1984            Total     +13    117
# 14  1984            Total     +14     82
# 15  1984            Total  +15-19    211
# 16  1984            Total  +20-24     71
# 17  1984            Total    +25+     39
# 18  1984            Total      -1   1334
# 19  1984            Total      -2    643
# 20  1984            Total      -3    362
# 21  1984            Total      -4    215
# ...

# %%
df.shape
# Out:
# (2520, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     2520 non-null   int64
#  1   level_1  2520 non-null   object
#  2   level_2  2520 non-null   object
#  3   value    2520 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 78.9+ KB

# %%
df.describe()
# Out:
#               year        value
# count  2520.000000  2520.000000
# mean   2001.000000   686.936905
# std      10.101509   829.824716
# min    1984.000000     4.000000
# 25%    1992.000000   160.000000
# 50%    2001.000000   303.500000
# 75%    2010.000000   817.500000
# max    2018.000000  4069.000000

# %%
cust_sell = df[df.year == '1984']
cust_sell
# Out:
# Empty DataFrame
# Columns: [year, level_1, level_2, value]
# Index: []

# %%
year1984=df.loc[df['year'] == 1984]

# %%
year1984
# Out:
#     year      level_1                           level_2  value
# 0   1984        Total                          Same Age   2506
# 1   1984        Total             Groom Older By 1 Year   3069
# 2   1984        Total            Groom Older By 2 Years   3168
# 3   1984        Total            Groom Older By 3 Years   3036
# 4   1984        Total            Groom Older By 4 Years   2590
# ..   ...          ...                               ...    ...
# 67  1984  Remarriages          Groom Younger By 2 Years     58
# 68  1984  Remarriages          Groom Younger By 3 Years     51
# 69  1984  Remarriages          Groom Younger By 4 Years     47
# 70  1984  Remarriages        Groom Younger By 5-9 Years    113
# 71  1984  Remarriages  Groom Younger By 10 Years & Over     43
#
# [72 rows x 4 columns]

# %%
print(df.columns)
# Out:
# Index(['year', 'level_1', 'level_2', 'value'], dtype='object')

# %%
remar=df.loc[(df['year'] == 1984) & (df['level_1'] == 'Remarriages')]
remar
# Out:
#     year      level_1                           level_2  value
# 48  1984  Remarriages                          Same Age    102
# 49  1984  Remarriages             Groom Older By 1 Year    112
# 50  1984  Remarriages            Groom Older By 2 Years    149
# 51  1984  Remarriages            Groom Older By 3 Years    114
# 52  1984  Remarriages            Groom Older By 4 Years    120
# 53  1984  Remarriages            Groom Older By 5 Years    120
# 54  1984  Remarriages            Groom Older By 6 Years    125
# 55  1984  Remarriages            Groom Older By 7 Years    125
# 56  1984  Remarriages            Groom Older By 8 Years    104
# 57  1984  Remarriages            Groom Older By 9 Years     80
# 58  1984  Remarriages           Groom Older By 10 Years     77
# 59  1984  Remarriages           Groom Older By 11 Years     64
# 60  1984  Remarriages           Groom Older By 12 Years     50
# 61  1984  Remarriages           Groom Older By 13 Years     46
# ...

# %%
remar['level_2'].value_counts()
# Out:
# Groom Older By 5 Years              1
# Groom Younger By 1 Year             1
# Groom Older By 8 Years              1
# Groom Older By 9 Years              1
# Groom Older By 13 Years             1
# Groom Older By 20-24 Years          1
# Groom Younger By 3 Years            1
# Groom Older By 12 Years             1
# Groom Older By 14 Years             1
# Groom Younger By 5-9 Years          1
# Groom Younger By 10 Years & Over    1
# Groom Older By 25 Years & Over      1
# Groom Older By 6 Years              1
# Groom Older By 10 Years             1
# Same Age                            1
# Groom Older By 7 Years              1
# Groom Older By 4 Years              1
# Groom Older By 3 Years              1
# Groom Older By 1 Year               1
# Groom Older By 11 Years             1
# Groom Older By 2 Years              1
# Groom Older By 15-19 Years          1
# Groom Younger By 2 Years            1
# Groom Younger By 4 Years            1
# Name: level_2, dtype: int64

# %%
# remar['level_2'].value_counts().plot(kind='pie', figsize=(6,6))
plot = remar.plot.pie( figsize=(20, 20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-6052b6dd941f> in <module>
#       1 # remar['level_2'].value_counts().plot(kind='pie', figsize=(6,6))
# ----> 2 plot = remar.plot.pie( figsize=(20, 20))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in pie(self, **kwargs)
#    1531             and not kwargs.get("subplots", False)
#    1532         ):
# -> 1533             raise ValueError("pie requires either y column or 'subplots=True'")
#    1534         return self(kind="pie", **kwargs)
#    1535
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
ax = remar['level_2'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_xlabel('level_2'), ax.set_ylabel('value')
# Out:
# (Text(0.5, 0, 'level_2'), Text(0, 0.5, 'value'))

# %%
# df.dtypes
ax = remar.plot(x="level_2",y='value')

# %%
# df["level_2"].replace({"a": "x", "b": "y"}, inplace=True)
remar["level_2"].replace({
'Groom Older By 5 Years':'+5',
    'Groom Younger By 1 Year': '-1' ,          
    'Groom Older By 8 Years' :'+8',           
    'Groom Older By 9 Years' :'+9' ,          
    'Groom Older By 13 Years' :'+13',           
    'Groom Older By 20-24 Years':'+20-24',        
    'Groom Younger By 3 Years'  :'-3',         
    'Groom Older By 12 Years':'+12',             
    'Groom Older By 14 Years':'+14',            
    'Groom Younger By 5-9 Years'  :'-5-9',        
    'Groom Younger By 10 Years & Over':'-10+',    
    'Groom Older By 25 Years & Over' :'+25+',    
    'Groom Older By 6 Years' :'+6',             
    'Groom Older By 10 Years'  :'+10',          
    'Same Age' :'=0',              
    'Groom Older By 7 Years':'+7',              
    'Groom Older By 4 Years'  :'+4',           
    'Groom Older By 3 Years' :'+3',             
    'Groom Older By 1 Year'  :'+1',             
    'Groom Older By 11 Years' :'+11',            
    'Groom Older By 2 Years'  :'+2',            
    'Groom Older By 15-19 Years' :'+15-19',        
    'Groom Younger By 2 Years' :'-2',        
    'Groom Younger By 4 Years' :'-4'
}, inplace=True)
remar
# Out:
#     year      level_1 level_2  value
# 48  1984  Remarriages      =0    102
# 49  1984  Remarriages      +1    112
# 50  1984  Remarriages      +2    149
# 51  1984  Remarriages      +3    114
# 52  1984  Remarriages      +4    120
# 53  1984  Remarriages      +5    120
# 54  1984  Remarriages      +6    125
# 55  1984  Remarriages      +7    125
# 56  1984  Remarriages      +8    104
# 57  1984  Remarriages      +9     80
# 58  1984  Remarriages     +10     77
# 59  1984  Remarriages     +11     64
# 60  1984  Remarriages     +12     50
# 61  1984  Remarriages     +13     46
# 62  1984  Remarriages     +14     37
# 63  1984  Remarriages  +15-19    122
# 64  1984  Remarriages  +20-24     52
# 65  1984  Remarriages    +25+     31
# 66  1984  Remarriages      -1    105
# 67  1984  Remarriages      -2     58
# 68  1984  Remarriages      -3     51
# 69  1984  Remarriages      -4     47
# 70  1984  Remarriages    -5-9    113
# 71  1984  Remarriages    -10+     43

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
ax = sns.barplot("level_2",y='value', data=remar)
sns.set(rc = {'figure.figsize':(12,8)})
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fmarriage1984=df.loc[(df['year'] == 1984) & (df['level_1'] == 'First Marriages')]

fmarriage1984
# Out:
#     year          level_1                           level_2  value
# 24  1984  First Marriages                          Same Age   2404
# 25  1984  First Marriages             Groom Older By 1 Year   2957
# 26  1984  First Marriages            Groom Older By 2 Years   3019
# 27  1984  First Marriages            Groom Older By 3 Years   2922
# 28  1984  First Marriages            Groom Older By 4 Years   2470
# 29  1984  First Marriages            Groom Older By 5 Years   1857
# 30  1984  First Marriages            Groom Older By 6 Years   1291
# 31  1984  First Marriages            Groom Older By 7 Years   1012
# 32  1984  First Marriages            Groom Older By 8 Years    680
# 33  1984  First Marriages            Groom Older By 9 Years    436
# 34  1984  First Marriages           Groom Older By 10 Years    270
# 35  1984  First Marriages           Groom Older By 11 Years    191
# 36  1984  First Marriages           Groom Older By 12 Years    117
# ...

# %%
fmarriage1984["level_2"].replace({
'Groom Older By 5 Years':'+5',
    'Groom Younger By 1 Year': '-1' ,          
    'Groom Older By 8 Years' :'+8',           
    'Groom Older By 9 Years' :'+9' ,          
    'Groom Older By 13 Years' :'+13',           
    'Groom Older By 20-24 Years':'+20-24',        
    'Groom Younger By 3 Years'  :'-3',         
    'Groom Older By 12 Years':'+12',             
    'Groom Older By 14 Years':'+14',            
    'Groom Younger By 5-9 Years'  :'-5-9',        
    'Groom Younger By 10 Years & Over':'-10+',    
    'Groom Older By 25 Years & Over' :'+25+',    
    'Groom Older By 6 Years' :'+6',             
    'Groom Older By 10 Years'  :'+10',          
    'Same Age' :'=0',              
    'Groom Older By 7 Years':'+7',              
    'Groom Older By 4 Years'  :'+4',           
    'Groom Older By 3 Years' :'+3',             
    'Groom Older By 1 Year'  :'+1',             
    'Groom Older By 11 Years' :'+11',            
    'Groom Older By 2 Years'  :'+2',            
    'Groom Older By 15-19 Years' :'+15-19',        
    'Groom Younger By 2 Years' :'-2',        
    'Groom Younger By 4 Years' :'-4'
}, inplace=True)
fmarriage1984
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
#     year          level_1 level_2  value
# 24  1984  First Marriages      =0   2404
# 25  1984  First Marriages      +1   2957
# 26  1984  First Marriages      +2   3019
# 27  1984  First Marriages      +3   2922
# 28  1984  First Marriages      +4   2470
# 29  1984  First Marriages      +5   1857
# 30  1984  First Marriages      +6   1291
# 31  1984  First Marriages      +7   1012
# 32  1984  First Marriages      +8    680
# 33  1984  First Marriages      +9    436
# 34  1984  First Marriages     +10    270
# 35  1984  First Marriages     +11    191
# 36  1984  First Marriages     +12    117
# 37  1984  First Marriages     +13     71
# ...

# %%
sns.set_theme(style="whitegrid")
ax = sns.barplot("level_2",y='value', data=fmarriage1984)
sns.set(rc = {'figure.figsize':(12,8)})
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#2018
fmarriage=df.loc[(df['year'] == 2018) & (df['level_1'] == 'First Marriages')]

fmarriage
# Out:
#       year          level_1                           level_2  value
# 2472  2018  First Marriages                          Same Age   3434
# 2473  2018  First Marriages             Groom Older By 1 Year   3148
# 2474  2018  First Marriages            Groom Older By 2 Years   2865
# 2475  2018  First Marriages            Groom Older By 3 Years   2293
# 2476  2018  First Marriages            Groom Older By 4 Years   1555
# 2477  2018  First Marriages            Groom Older By 5 Years   1081
# 2478  2018  First Marriages            Groom Older By 6 Years    806
# 2479  2018  First Marriages            Groom Older By 7 Years    556
# 2480  2018  First Marriages            Groom Older By 8 Years    372
# 2481  2018  First Marriages            Groom Older By 9 Years    250
# 2482  2018  First Marriages           Groom Older By 10 Years    196
# 2483  2018  First Marriages           Groom Older By 11 Years    153
# 2484  2018  First Marriages           Groom Older By 12 Years    106
# ...

# %%
fmarriage["level_2"].replace({
'Groom Older By 5 Years':'+5',
    'Groom Younger By 1 Year': '-1' ,          
    'Groom Older By 8 Years' :'+8',           
    'Groom Older By 9 Years' :'+9' ,          
    'Groom Older By 13 Years' :'+13',           
    'Groom Older By 20-24 Years':'+20-24',        
    'Groom Younger By 3 Years'  :'-3',         
    'Groom Older By 12 Years':'+12',             
    'Groom Older By 14 Years':'+14',            
    'Groom Younger By 5-9 Years'  :'-5-9',        
    'Groom Younger By 10 Years & Over':'-10+',    
    'Groom Older By 25 Years & Over' :'+25+',    
    'Groom Older By 6 Years' :'+6',             
    'Groom Older By 10 Years'  :'+10',          
    'Same Age' :'=0',              
    'Groom Older By 7 Years':'+7',              
    'Groom Older By 4 Years'  :'+4',           
    'Groom Older By 3 Years' :'+3',             
    'Groom Older By 1 Year'  :'+1',             
    'Groom Older By 11 Years' :'+11',            
    'Groom Older By 2 Years'  :'+2',            
    'Groom Older By 15-19 Years' :'+15-19',        
    'Groom Younger By 2 Years' :'-2',        
    'Groom Younger By 4 Years' :'-4'
}, inplace=True)

fmarriage
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
#       year          level_1 level_2  value
# 2472  2018  First Marriages      =0   3434
# 2473  2018  First Marriages      +1   3148
# 2474  2018  First Marriages      +2   2865
# 2475  2018  First Marriages      +3   2293
# 2476  2018  First Marriages      +4   1555
# 2477  2018  First Marriages      +5   1081
# 2478  2018  First Marriages      +6    806
# 2479  2018  First Marriages      +7    556
# 2480  2018  First Marriages      +8    372
# 2481  2018  First Marriages      +9    250
# 2482  2018  First Marriages     +10    196
# 2483  2018  First Marriages     +11    153
# 2484  2018  First Marriages     +12    106
# ...

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")
ax = sns.barplot("level_2",y='value', data=fmarriage)
sns.set(rc = {'figure.figsize':(12,8)})
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
remar2018=df.loc[(df['year'] == 2018) & (df['level_1'] == 'Remarriages')]
remar2018
# Out:
#       year      level_1                           level_2  value
# 2496  2018  Remarriages                          Same Age    406
# 2497  2018  Remarriages             Groom Older By 1 Year    362
# 2498  2018  Remarriages            Groom Older By 2 Years    361
# 2499  2018  Remarriages            Groom Older By 3 Years    339
# 2500  2018  Remarriages            Groom Older By 4 Years    313
# 2501  2018  Remarriages            Groom Older By 5 Years    336
# 2502  2018  Remarriages            Groom Older By 6 Years    314
# 2503  2018  Remarriages            Groom Older By 7 Years    271
# 2504  2018  Remarriages            Groom Older By 8 Years    260
# 2505  2018  Remarriages            Groom Older By 9 Years    248
# 2506  2018  Remarriages           Groom Older By 10 Years    195
# 2507  2018  Remarriages           Groom Older By 11 Years    180
# 2508  2018  Remarriages           Groom Older By 12 Years    142
# ...

# %%
remar2018["level_2"].replace({
'Groom Older By 5 Years':'+5',
    'Groom Younger By 1 Year': '-1' ,          
    'Groom Older By 8 Years' :'+8',           
    'Groom Older By 9 Years' :'+9' ,          
    'Groom Older By 13 Years' :'+13',           
    'Groom Older By 20-24 Years':'+20-24',        
    'Groom Younger By 3 Years'  :'-3',         
    'Groom Older By 12 Years':'+12',             
    'Groom Older By 14 Years':'+14',            
    'Groom Younger By 5-9 Years'  :'-5-9',        
    'Groom Younger By 10 Years & Over':'-10+',    
    'Groom Older By 25 Years & Over' :'+25+',    
    'Groom Older By 6 Years' :'+6',             
    'Groom Older By 10 Years'  :'+10',          
    'Same Age' :'=0',              
    'Groom Older By 7 Years':'+7',              
    'Groom Older By 4 Years'  :'+4',           
    'Groom Older By 3 Years' :'+3',             
    'Groom Older By 1 Year'  :'+1',             
    'Groom Older By 11 Years' :'+11',            
    'Groom Older By 2 Years'  :'+2',            
    'Groom Older By 15-19 Years' :'+15-19',        
    'Groom Younger By 2 Years' :'-2',        
    'Groom Younger By 4 Years' :'-4'
}, inplace=True)

remar2018
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
#       year      level_1 level_2  value
# 2496  2018  Remarriages      =0    406
# 2497  2018  Remarriages      +1    362
# 2498  2018  Remarriages      +2    361
# 2499  2018  Remarriages      +3    339
# 2500  2018  Remarriages      +4    313
# 2501  2018  Remarriages      +5    336
# 2502  2018  Remarriages      +6    314
# 2503  2018  Remarriages      +7    271
# 2504  2018  Remarriages      +8    260
# 2505  2018  Remarriages      +9    248
# 2506  2018  Remarriages     +10    195
# 2507  2018  Remarriages     +11    180
# 2508  2018  Remarriages     +12    142
# 2509  2018  Remarriages     +13    148
# ...

# %%
sns.set_theme(style="whitegrid")
ax = sns.barplot("level_2",y='value', data=remar2018)
sns.set(rc = {'figure.figsize':(15,15)})
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df["level_2"].replace({
'Groom Older By 5 Years':'+5',
    'Groom Younger By 1 Year': '-1' ,          
    'Groom Older By 8 Years' :'+8',           
    'Groom Older By 9 Years' :'+9' ,          
    'Groom Older By 13 Years' :'+13',           
    'Groom Older By 20-24 Years':'+20-24',        
    'Groom Younger By 3 Years'  :'-3',         
    'Groom Older By 12 Years':'+12',             
    'Groom Older By 14 Years':'+14',            
    'Groom Younger By 5-9 Years'  :'-5-9',        
    'Groom Younger By 10 Years & Over':'-10+',    
    'Groom Older By 25 Years & Over' :'+25+',    
    'Groom Older By 6 Years' :'+6',             
    'Groom Older By 10 Years'  :'+10',          
    'Same Age' :'=0',              
    'Groom Older By 7 Years':'+7',              
    'Groom Older By 4 Years'  :'+4',           
    'Groom Older By 3 Years' :'+3',             
    'Groom Older By 1 Year'  :'+1',             
    'Groom Older By 11 Years' :'+11',            
    'Groom Older By 2 Years'  :'+2',            
    'Groom Older By 15-19 Years' :'+15-19',        
    'Groom Younger By 2 Years' :'-2',        
    'Groom Younger By 4 Years' :'-4'
}, inplace=True)

df
# Out:
#       year      level_1 level_2  value
# 0     1984        Total      =0   2506
# 1     1984        Total      +1   3069
# 2     1984        Total      +2   3168
# 3     1984        Total      +3   3036
# 4     1984        Total      +4   2590
# ...    ...          ...     ...    ...
# 2515  2018  Remarriages      -2    191
# 2516  2018  Remarriages      -3    152
# 2517  2018  Remarriages      -4    141
# 2518  2018  Remarriages    -5-9    329
# 2519  2018  Remarriages    -10+    167
#
# [2520 rows x 4 columns]

# %%
# fmarriage=df.loc[(df['year'] == 2018) & (df['level_1'] == 'First Marriages')]


blah=df.loc[(df['level_1'] == 'Remarriages') & (df['level_2'] == '+15-19')]
blah

# %%
fmar=df.loc[(df['level_1'] == 'First Marriages') & (df['level_2'] == '+15-19')]
fmar
# Out:
#       year          level_1 level_2  value
# 39    1984  First Marriages  +15-19     89
# 111   1985  First Marriages  +15-19     80
# 183   1986  First Marriages  +15-19     66
# 255   1987  First Marriages  +15-19     78
# 327   1988  First Marriages  +15-19    102
# 399   1989  First Marriages  +15-19    104
# 471   1990  First Marriages  +15-19    122
# 543   1991  First Marriages  +15-19    119
# 615   1992  First Marriages  +15-19    139
# 687   1993  First Marriages  +15-19    170
# 759   1994  First Marriages  +15-19    224
# 831   1995  First Marriages  +15-19    242
# 903   1996  First Marriages  +15-19    247
# 975   1997  First Marriages  +15-19    252
# 1047  1998  First Marriages  +15-19    265
# 1119  1999  First Marriages  +15-19    323
# 1191  2000  First Marriages  +15-19    290
# 1263  2001  First Marriages  +15-19    302
# 1335  2002  First Marriages  +15-19    334
# 1407  2003  First Marriages  +15-19    297
# 1479  2004  First Marriages  +15-19    352
# ...

# %%
#Chart 
sns.lineplot(data=blah, x="year", y="value")
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %%
#Chart 
sns.lineplot(data=fmar, x="year", y="value")
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %%
undata=pd.read_excel('unpd_data.xls', index_col=1)  
undata
# Out:
#              Country or area  YearStart  YearEnd    Sex     MaritalStatus  \
# ISO code
# 4                Afghanistan       1972     1974    Men          Divorced
# 4                Afghanistan       1972     1974    Men          Divorced
# 4                Afghanistan       1972     1974    Men          Divorced
# 4                Afghanistan       1972     1974    Men          Divorced
# 4                Afghanistan       1972     1974    Men          Divorced
# ...                      ...        ...      ...    ...               ...
# 214       Dominican Republic       1981     1981  Women          Divorced
# 214       Dominican Republic       1981     1981  Women          Divorced
# 214       Dominican Republic       1981     1981  Women  Consensual union
# 214       Dominican Republic       1981     1981  Women  Consensual union
# 214       Dominican Republic       1981     1981  Women  Consensual union
#
# ...

# %%
ddf=pd.read_csv('unpd_data.csv', index_col=1) 
ddf
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (19,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Country or area  YearStart  YearEnd    Sex MaritalStatus  \
# ISO code
# 4            Afghanistan       1972     1974    Men      Divorced
# 4            Afghanistan       1972     1974    Men      Divorced
# 4            Afghanistan       1972     1974    Men      Divorced
# 4            Afghanistan       1972     1974    Men      Divorced
# 4            Afghanistan       1972     1974    Men      Divorced
# ...                  ...        ...      ...    ...           ...
# 716             Zimbabwe       2017     2017  Women       Widowed
# 716             Zimbabwe       2017     2017  Women       Widowed
# 716             Zimbabwe       2017     2017  Women       Widowed
# ...

# %%
# undata=undata.drop(columns=['Non-standard_AgeGroups', 'Series_contains_Non-standard_AgeGroups', 'DataValue'])

# %%
# undata=undata.drop(columns=['Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22'])
# undata
# Out:
#              Country or area  YearStart  YearEnd    Sex     MaritalStatus  \
# ISO code
# 4                Afghanistan       1972     1974    Men          Divorced
# 4                Afghanistan       1972     1974    Men          Divorced
# 4                Afghanistan       1972     1974    Men          Divorced
# 4                Afghanistan       1972     1974    Men          Divorced
# 4                Afghanistan       1972     1974    Men          Divorced
# ...                      ...        ...      ...    ...               ...
# 214       Dominican Republic       1981     1981  Women          Divorced
# 214       Dominican Republic       1981     1981  Women          Divorced
# 214       Dominican Republic       1981     1981  Women  Consensual union
# 214       Dominican Republic       1981     1981  Women  Consensual union
# 214       Dominican Republic       1981     1981  Women  Consensual union
#
# ...

# %%
ddf=ddf.drop(columns=['Non-standard_AgeGroups', 'Series_contains_Non-standard_AgeGroups', 'Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22'])
ddf
# Out:
#          Country or area  YearStart  YearEnd    Sex MaritalStatus AgeGroup  \
# ISO code
# 4            Afghanistan       1972     1974    Men      Divorced  [15-19]
# 4            Afghanistan       1972     1974    Men      Divorced  [20-24]
# 4            Afghanistan       1972     1974    Men      Divorced  [25-29]
# 4            Afghanistan       1972     1974    Men      Divorced  [30-34]
# 4            Afghanistan       1972     1974    Men      Divorced  [35-39]
# ...                  ...        ...      ...    ...           ...      ...
# 716             Zimbabwe       2017     2017  Women       Widowed  [55-59]
# 716             Zimbabwe       2017     2017  Women       Widowed  [60-64]
# 716             Zimbabwe       2017     2017  Women       Widowed  [65-69]
# 716             Zimbabwe       2017     2017  Women       Widowed  [70-74]
# 716             Zimbabwe       2017     2017  Women       Widowed    [75+]
#
# ...

# %%
# del undata

# %%
ddf.columns
# Out:
# Index(['Country or area', 'YearStart', 'YearEnd', 'Sex', 'MaritalStatus',
#        'AgeGroup', 'AgeStart', 'AgeEnd', 'DataProcess',
#        'DataCatalog ShortName', 'DataCatalog ID', 'DataCatalog LongName',
#        'Data Source'],
#       dtype='object')

# %%
undata.columns
# Out:
# Index(['Country or area', 'YearStart', 'YearEnd', 'Sex', 'MaritalStatus',
#        'AgeGroup', 'AgeStart', 'AgeEnd', 'DataProcess',
#        'DataCatalog ShortName', 'DataCatalog ID', 'DataCatalog LongName',
#        'Data Source'],
#       dtype='object')

# %%
undata.loc[(undata['Country or area'] == 'Maldives')]
# Out:
# Empty DataFrame
# Columns: [Country or area, YearStart, YearEnd, Sex, MaritalStatus, AgeGroup, AgeStart, AgeEnd, DataProcess, DataCatalog ShortName, DataCatalog ID, DataCatalog LongName, Data Source]
# Index: []

# %%
# for col in undata:
#   print(undata[col].unique())

ddf['Country or area'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia (Plurinational State of)',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'China, Hong Kong SAR',
#        'China, Macao SAR', 'China, Taiwan Province of China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Côte d'Ivoire",
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czechia',
#        "Dem. People's Rep. of Korea", 'Democratic Republic of the Congo',
# ...

# %%
for col in ddf:
  print(ddf[col].unique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Angola' 'Anguilla'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan'
#  'Bolivia (Plurinational State of)' 'Bosnia and Herzegovina' 'Botswana'
#  'Brazil' 'British Virgin Islands' 'Brunei Darussalam' 'Bulgaria'
#  'Burkina Faso' 'Burundi' 'Cabo Verde' 'Cambodia' 'Cameroon' 'Canada'
#  'Cayman Islands' 'Central African Republic' 'Chad' 'Channel Islands'
#  'Chile' 'China' 'China, Hong Kong SAR' 'China, Macao SAR'
#  'China, Taiwan Province of China' 'Colombia' 'Comoros' 'Congo'
#  'Cook Islands' 'Costa Rica' "Côte d'Ivoire" 'Croatia' 'Cuba' 'Curaçao'
#  'Cyprus' 'Czechia' "Dem. People's Rep. of Korea"
#  'Democratic Republic of the Congo' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'Equatorial Guinea'
# ...

# %%
ddf.columns
# Out:
# Index(['Country or area', 'YearStart', 'YearEnd', 'Sex', 'MaritalStatus',
#        'AgeGroup', 'AgeStart', 'AgeEnd', 'DataProcess',
#        'DataCatalog ShortName', 'DataCatalog ID', 'DataCatalog LongName',
#        'Data Source'],
#       dtype='object')

# %%
# american = ddf['Country or area'] == "Canada"
# american
ind=ddf.loc[(ddf['Country or area'] == 'India')& (ddf['MaritalStatus'] == 'Married')]
ind
# Out:
#          Country or area  YearStart  YearEnd    Sex MaritalStatus AgeGroup  \
# ISO code
# 356                India       1981     1981  Women       Married  [10-14]
# 356                India       1981     1981  Women       Married  [15-19]
# 356                India       1981     1981  Women       Married  [20-24]
# 356                India       1981     1981  Women       Married  [25-29]
# 356                India       1981     1981  Women       Married  [30-34]
# ...                  ...        ...      ...    ...           ...      ...
# 356                India       2015     2016  Women       Married  [25-29]
# 356                India       2015     2016  Women       Married  [30-34]
# 356                India       2015     2016  Women       Married  [35-39]
# 356                India       2015     2016  Women       Married  [40-44]
# 356                India       2015     2016  Women       Married  [45-49]
#
# ...

# %%
# tes=ind.loc[(ind['YearStart'] == '1984')]

# %%
sns.set_theme(style="whitegrid")
ax = sns.barplot("AgeGroup",y='DataValue', data=ind)
sns.set(rc = {'figure.figsize':(15,15)})
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
usa=ddf.loc[(ddf['Country or area'] == 'United States of America')& (ddf['MaritalStatus'] == 'Married')]
usa
# Out:
#                    Country or area  YearStart  YearEnd    Sex MaritalStatus  \
# ISO code
# 840       United States of America       1970     1970    Men       Married
# 840       United States of America       1970     1970    Men       Married
# 840       United States of America       1970     1970    Men       Married
# 840       United States of America       1970     1970    Men       Married
# 840       United States of America       1970     1970    Men       Married
# ...                            ...        ...      ...    ...           ...
# 840       United States of America       2012     2012  Women       Married
# 840       United States of America       2012     2012  Women       Married
# 840       United States of America       2012     2012  Women       Married
# 840       United States of America       2012     2012  Women       Married
# 840       United States of America       2012     2012  Women       Married
#
# ...

# %%
sns.set_theme(style="whitegrid")
ax = sns.barplot("AgeGroup",y='DataValue', data=usa)
sns.set(rc = {'figure.figsize':(15,15)})
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import os
import sys
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
import math
from IPython.core.interactiveshell import InteractiveShell
from datetime import *
import statistics as stats
# This helps auto print out the items without explixitly using 'print'
InteractiveShell.ast_node_interactivity = "all" 
# %matplotlib inline

# %%
# !pip install pyspark;

# %%
import pyspark
from pyspark.rdd import RDD
from pyspark.sql import Row
from pyspark.sql import DataFrame
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
from pyspark.sql import functions
from pyspark.sql.functions import lit, desc, col, size, array_contains\
, isnan, udf, hour, array_min, array_max, countDistinct
from pyspark.sql.types import *

MAX_MEMORY = '15G'
# Initialize a spark session.
conf = pyspark.SparkConf().setMaster("local[*]") \
        .set('spark.executor.heartbeatInterval', 10000) \
        .set('spark.network.timeout', 10000) \
        .set("spark.core.connection.ack.wait.timeout", "3600") \
        .set("spark.executor.memory", MAX_MEMORY) \
        .set("spark.driver.memory", MAX_MEMORY)
def init_spark():
    spark = SparkSession \
        .builder \
        .appName("Pyspark guide") \
        .config(conf=conf) \
        .getOrCreate()
    return spark

# %%
#Age in which people get married
sdf = spark.read.csv("smam.csv")
spark = init_spark()

# %%
print('Data overview')
sdf.printSchema()
print('Columns overview')
pd.DataFrame(sdf.dtypes, columns = ['Column Name','Data type'])
# Out:
# Data overview
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#
# Columns overview
#    Column Name Data type
# 0          _c0    string
# 1          _c1    string
# 2          _c2    string
# 3          _c3    string
# 4          _c4    string
# 5          _c5    string
# 6          _c6    string
# 7          _c7    string
# 8          _c8    string
# 9          _c9    string
# 10        _c10    string
# 11        _c11    string
# 12        _c12    string

# %%
# Detect missing values
print('Columns overview')
pd.DataFrame(sdf.dtypes, columns = ['Column Name','Data type'])
# Out:
# Columns overview
#    Column Name Data type
# 0          _c0    string
# 1          _c1    string
# 2          _c2    string
# 3          _c3    string
# 4          _c4    string
# 5          _c5    string
# 6          _c6    string
# 7          _c7    string
# 8          _c8    string
# 9          _c9    string
# 10        _c10    string
# 11        _c11    string
# 12        _c12    string

# %%
#Testing same code with Pandas
#Age in which people get married
testing1=pd.read_csv('smam.csv', index_col=3) 
testing1
# Out:
#         Country or area  ISO code  YearStart    Sex  DataValue DataProcess  \
# YearEnd
# 1974.0      Afghanistan       4.0     1972.0    Men       26.0      Survey
# 1974.0      Afghanistan       4.0     1972.0  Women       18.1      Survey
# 1979.0      Afghanistan       4.0     1979.0    Men       25.3      Census
# 1979.0      Afghanistan       4.0     1979.0  Women       17.8      Census
# 2010.0      Afghanistan       4.0     2010.0  Women       21.5      Survey
# ...                 ...       ...        ...    ...        ...         ...
# NaN                 NaN       NaN        NaN    NaN        NaN         NaN
# NaN                 NaN       NaN        NaN    NaN        NaN         NaN
# NaN                 NaN       NaN        NaN    NaN        NaN         NaN
# NaN                 NaN       NaN        NaN    NaN        NaN         NaN
# NaN                 NaN       NaN        NaN    NaN        NaN         NaN
#
#         DataCatalog ShortName  DataCatalog ID  \
# YearEnd
# ...

# %%
indtest=testing1.loc[(testing1['Country or area'] == 'India')]
indtest
# Out:
#         Country or area  ISO code  YearStart    Sex  DataValue DataProcess  \
# YearEnd
# 1971.0            India     356.0     1971.0    Men       22.7      Census
# 1971.0            India     356.0     1971.0  Women       17.7      Census
# 1981.0            India     356.0     1981.0    Men       23.4      Census
# 1981.0            India     356.0     1981.0  Women       18.7      Census
# 1991.0            India     356.0     1991.0    Men       24.0      Census
# 1991.0            India     356.0     1991.0  Women       19.3      Census
# 1993.0            India     356.0     1992.0    Men       24.3      Survey
# 1993.0            India     356.0     1992.0  Women       19.3      Survey
# 1993.0            India     356.0     1992.0  Women       19.2      Survey
# 1999.0            India     356.0     1998.0    Men       24.9      Survey
# 1999.0            India     356.0     1998.0  Women       19.9      Survey
# ...

# %%
import seaborn as sns

# %%
#Average Age Men and Women in India Get married

sns.set_theme(style="whitegrid")
ax = sns.barplot("Sex",y='DataValue', data=indtest)
sns.set(rc = {'figure.figsize':(15,15)})
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# plot0 = axs[0].bar(x=top_activities_by_gender_df['sex']
#                    , height=top_activities_by_gender_df['DataValue'])
# title0 = axs[0].set_title('Sex', fontsize='small')
# xlabel0 = axs[0].set_xlabel('Sex', fontsize='small')
# ylabel0 = axs[0].set_ylabel('Age', fontsize='small')
# xsticks_label = axs[0].set_xticklabels(top_activities_by_gender_df['sex']
#                                        , rotation='vertical', fontsize='small')

# %%
plot = indtest.boxplot(column='DataValue', by='Sex', fontsize='small', figsize=(6,7))

# %%
usa=testing1.loc[(testing1['Country or area'] == 'United States of America')]
usa
# Out:
#                   Country or area  ISO code  YearStart    Sex  DataValue  \
# YearEnd
# 1970.0   United States of America     840.0     1970.0    Men       23.5
# 1970.0   United States of America     840.0     1970.0  Women       21.5
# 1995.0   United States of America     840.0     1995.0  Women       23.3
# 2002.0   United States of America     840.0     2002.0    Men       24.0
# 2002.0   United States of America     840.0     2002.0  Women       23.7
# 2008.0   United States of America     840.0     2006.0  Women       23.7
# 2010.0   United States of America     840.0     2010.0    Men       29.2
# 2010.0   United States of America     840.0     2010.0  Women       27.5
#
#         DataProcess DataCatalog ShortName  DataCatalog ID  \
# YearEnd
# 1970.0       Census           1970 Census           321.0
# 1970.0       Census           1970 Census           321.0
# 1995.0       Survey             1995 NSFG          2861.0
# ...

# %%
plot = usa.boxplot(column='DataValue', by='Sex', fontsize='small', figsize=(6,7))

# %%
#Average Age Men and Women in USA Get married

sns.set_theme(style="whitegrid")
ax = sns.barplot("Sex",y='DataValue', data=usa)
sns.set(rc = {'figure.figsize':(8,10)})
# Out:
# /Users/temi/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
